# %% [markdown]
# This example performs wordcount operation on an article text specified in the path below, all using Apache spark context. It then prints the word frquency to the output screen.

# %%
from operator import add

from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("PythonWordCount").getOrCreate()

lines = spark.read.text("wordcount.txt").rdd.map(lambda r: r[0])
counts = lines.flatMap(lambda x: x.split(' ')).map(lambda x: (x, 1)).reduceByKey(add)
output = counts.collect()
for (word, count) in output:
    print("%s: %i" % (word, count))

spark.stop()
# Out:
# : 8
# limited: 3
# liquidity: 2
# four: 1
# $19,000,: 1
# sleep: 1
# Monday.The: 1
# whose: 1
# Vinnick,: 2
# third-biggest: 1
# electricity: 6
# under: 1
# worth: 2
# risk: 1
# Industry: 1
# side-by-side: 1
# every: 1
# Plattsburgh: 2
# vast: 1
# problems,: 2
# problems.: 1
# companies: 4
# unrelated: 1
# math: 1
# stereotypical: 1
# force: 1
# consistent: 1
# guidelines: 1
# likely: 3
# others,: 1
# between.There: 1
# estimated: 2
# machines: 1
# even: 4
# nature.: 1
# gold.: 1
# cybercrime.He: 1
# sales,: 1
# new: 18
# tips: 1
# increasing: 1
# seeks: 1
# told: 4
# evolving: 1
# mosquitoes.Mr.: 1
# never: 1
# drew: 1
# reported: 3
# concerns.“Enel: 1
# protection: 1
# blockchain,: 2
# path: 1
# 100: 2
# items: 1
# Tuesday: 2
# economics: 1
# can,”: 1
# company,: 5
# Group: 2
# St.: 3
# highly: 2
# building.The: 1
# forums: 1
# Prep,: 1
# swings: 1
# would: 10
# smelter: 1
# decentralized: 1
# coins: 6
# world's: 1
# said.This: 1
# call: 2
# supporters: 1
# phone: 1
# offline,: 1
# ...
